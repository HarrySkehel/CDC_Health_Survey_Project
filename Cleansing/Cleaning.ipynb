# %%
import pandas as pd
import dask.dataframe as df
import sqlalchemy as sq
import requests
import kagglehub
import psycopg2
import numpy as np
import json
import glob
import os
import zipfile as zf

# %%
Data_2011 = pd.read_csv('SourceData/2011.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Data_2011 = pd.read_csv('SourceData/2011.csv')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
#Dropping columns that are either all NA, NaN or are not in the CDC codes
Data_2011.drop(columns=['_DENSTR2', 'PRECALL', 'REPNUM', 'REPDEPTH', 'HAVHPAD','_GEOSTR'], axis = 1, inplace=True)
Data_2011.drop(columns=['FMONTH', 'DISPCODE','CTELENUM', 'NUMADULT', 'NUMWOMEN', 'CTELNUM1', 'CELLFON2',
'IYEAR', 'NUMMEN'], axis = 1, inplace = True)
Data_2011.head()
# Out:
#    _STATE        IDATE IMONTH   IDAY    INTVID         SEQNO          _PSU  \
# 0     1.0  b'01202011'  b'01'  b'20'  b'00118'  2.011000e+09  2.011000e+09
# 1     1.0  b'01142011'  b'01'  b'14'  b'00136'  2.011000e+09  2.011000e+09
# 2     1.0  b'01062011'  b'01'  b'06'  b'00140'  2.011001e+09  2.011001e+09
# 3     1.0  b'02012011'  b'02'  b'01'  b'00188'  2.011001e+09  2.011001e+09
# 4     1.0  b'02012011'  b'02'  b'01'  b'00118'  2.011001e+09  2.011001e+09
#
#    NATTMPTS  NRECSEL   NRECSTR  ...  _PNEUMO2  DRNKANY5      DROCDY3_  \
# 0       6.0   1662.0   56365.0  ...       NaN       1.0  4.300000e+01
# 1       6.0   1662.0   56365.0  ...       NaN       9.0  9.000000e+02
# 2       1.0   1689.0  113769.0  ...       9.0       1.0  1.400000e+01
# 3      15.0   2088.0   41627.0  ...       9.0       9.0  9.000000e+02
# 4      14.0   2088.0   41627.0  ...       NaN       2.0  5.397605e-79
#
#    _RFBING5      _DRNKDY4      _DRNKMO4  _RFDRHV4  _RFDRMN4  _RFDRWM4  \
# ...

# %%
#Updating NaN values to 9.0 for unknown, NaN represent questions that were not asked or missing. If they are questions relating to a specific gender, they will be dropped accordingly.
Data_2011.fillna(value=9.0, inplace=True)

# %%
# Out:
#    _STATE        IDATE IMONTH   IDAY    INTVID         SEQNO          _PSU  \
# 0     1.0  b'01202011'  b'01'  b'20'  b'00118'  2.011000e+09  2.011000e+09
# 1     1.0  b'01142011'  b'01'  b'14'  b'00136'  2.011000e+09  2.011000e+09
# 2     1.0  b'01062011'  b'01'  b'06'  b'00140'  2.011001e+09  2.011001e+09
# 3     1.0  b'02012011'  b'02'  b'01'  b'00188'  2.011001e+09  2.011001e+09
# 4     1.0  b'02012011'  b'02'  b'01'  b'00118'  2.011001e+09  2.011001e+09
#
#    NATTMPTS  NRECSEL   NRECSTR  ...  _PNEUMO2  DRNKANY5      DROCDY3_  \
# 0       6.0   1662.0   56365.0  ...       9.0       1.0  4.300000e+01
# 1       6.0   1662.0   56365.0  ...       9.0       9.0  9.000000e+02
# 2       1.0   1689.0  113769.0  ...       9.0       1.0  1.400000e+01
# 3      15.0   2088.0   41627.0  ...       9.0       9.0  9.000000e+02
# 4      14.0   2088.0   41627.0  ...       9.0       2.0  5.397605e-79
#
#    _RFBING5      _DRNKDY4      _DRNKMO4  _RFDRHV4  _RFDRMN4  _RFDRWM4  \
# ...

# %%
Data_2015 = pd.read_csv('SourceData/2015.csv')

# %%
#Data_2012.head()
#Data_2013.head()

Data_2015.fillna(value=9.0, inplace=True)
